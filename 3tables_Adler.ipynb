# %%
#import pandas
import pandas as pd

# %%
#upload the dataset
gitCloudRepo = 'https://github.com/542CompThink/Deliverable1/raw/main/'
fileName = "energy consum.csv"

# %%
energyCsm = pd.read_csv(gitCloudRepo + fileName)
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# /var/folders/fd/rkbd_2854zj04sh03zsspmf80000gn/T/ipykernel_2226/208059963.py in <module>
# ----> 1 energyCsm = pd.read_csv(gitCloudRepo + fileName)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
