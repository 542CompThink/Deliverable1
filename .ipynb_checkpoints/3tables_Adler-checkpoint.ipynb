# %%
#import pandas
import pandas as pd

# %%
#upload the dataset
gitCloudRepo = 'https://github.com/542CompThink/Deliverable1/raw/main/'
fileName = "energyconsum.csv"

# %%
energyCsm = pd.read_csv(gitCloudRepo + fileName)

# %% [markdown]
# The name of any datasets expected to be retrieved shouldn't contain blanks or other symbols

# %%
energyCsm
# Out:
#                                               name  \
# 0                                            Qatar
# 1                                        Singapore
# 2                                          Bahrain
# 3                             United Arab Emirates
# 4                                           Brunei
# ..                                             ...
# 207  Saint Helena, Ascension, and Tristan da Cunha
# 208                      Saint Pierre and Miquelon
# 209                       Turks and Caicos Islands
# 210                                         Tuvalu
# 211                                    Wake Island
#
#                                             slug          value  \
# 0                                          qatar  723,582,000.0
# 1                                      singapore  639,951,000.0
# 2                                        bahrain  547,976,000.0
# 3                           united-arab-emirates  471,788,000.0
# ...

# %% [markdown]
# the dataset 'energyCsm' has been updated by 2019

# %%
energyCsm.columns
# Out:
# Index(['name', 'slug', 'value', 'date_of_information', 'ranking', 'region'], dtype='object')

# %%
#drop the 4th and the 5th columns 
leave = [3,4]
energyCsm.drop(columns=energyCsm.columns[leave],inplace=True)#inplace!!

# %%
energyCsm
# Out:
#                                               name  \
# 0                                            Qatar
# 1                                        Singapore
# 2                                          Bahrain
# 3                             United Arab Emirates
# 4                                           Brunei
# ..                                             ...
# 207  Saint Helena, Ascension, and Tristan da Cunha
# 208                      Saint Pierre and Miquelon
# 209                       Turks and Caicos Islands
# 210                                         Tuvalu
# 211                                    Wake Island
#
#                                             slug          value  \
# 0                                          qatar  723,582,000.0
# 1                                      singapore  639,951,000.0
# 2                                        bahrain  547,976,000.0
# 3                           united-arab-emirates  471,788,000.0
# ...

# %%
# add '.to_list()' to see beyond!
energyCsm.columns.to_list()
# Out:
# ['name', 'slug', 'value', 'region']

# %%
energyCsm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    212 non-null    object
#  1   slug    212 non-null    object
#  2   value   212 non-null    object
#  3   region  212 non-null    object
# dtypes: object(4)
# memory usage: 6.8+ KB
